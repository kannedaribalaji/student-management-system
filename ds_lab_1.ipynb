# %% [markdown]
# <a href="https://colab.research.google.com/github/kannedaribalaji/student-management-system/blob/main/ds_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# k. balaji
#23102A010340
# cse ai & ml
url = 'https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv'
df = pd.read_csv(url)
print(df.head())

df.to_csv("output.csv", index=False)
# Out:
#    Index   Height(Inches)"   "Weight(Pounds)"
# 0      1             65.78             112.99
# 1      2             71.52             136.49
# 2      3             69.40             153.03
# 3      4             68.22             142.34
# 4      5             67.79             144.30

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

df = pd.read_csv(url)

print(df.head())

# Convert to JSON
df.to_json("output.json", orient="records", indent=4)

print("JSON file created successfully!")
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# JSON file created successfully!

# %%
import pandas as pd

# Read CSV from URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

print(df.head())

# Save as .xlsx using openpyxl
df.to_excel("tips.xlsx", index=False, engine="openpyxl")

print("tips.xlsx created successfully!")
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# tips.xlsx created successfully!
